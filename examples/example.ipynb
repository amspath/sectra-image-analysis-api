# %%
token = "..."
url = "..."
slide_id = "..."

# %%
from sectra_client import SectraClient

client = SectraClient(
    url=url,
    token=token
)

# %%
client.version_info
# Out:
# ApplicationInfo(apiVersion='1.10', softwareVersion='4.2.0.22617')

# %%
info = client.get_image_metadata(slide_id, extended=True, phi=True)
print(info.accessionNumber)
# Out:
# A20250813074542

# %%
label = client.get_label_image(slide_id)

# %%
client.download_slide_files(slide_id, output_dir="./")
# Out:
# [PosixPath('i0000,0000b.dcm'),
#  PosixPath('i0001,0000b.dcm'),
#  PosixPath('i0003,0000b.dcm'),
#  PosixPath('i0004,0000b.dcm'),
#  PosixPath('i0005,0000b.dcm'),
#  PosixPath('i0006,0000b.dcm'),
#  PosixPath('i0007,0000b.dcm'),
#  PosixPath('i0008,0000b.dcm'),
#  PosixPath('i0009,0000b.dcm'),
#  PosixPath('i0010,0000b.dcm'),
#  PosixPath('i0011,0000b.dcm'),
#  PosixPath('i0012,0000b.dcm')]
